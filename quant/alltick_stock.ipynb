# %%
import time
import requests
import json

#extract headers
test_headers={'Content_type':'application/json'}
klines_100w_url='https://quote.alltick.io/quote-stock-b-api/kline?token=69d6ce419ba4e758ec62bc6250e3d778-c-app&query={%20%22trace%22:%20%223baaa938-f92c-4a74-a228-fd49d5e2f8bc-1678419657806%22,%20%22data%22:%20{%20%22code%22:%20%223988.HK%22,%20%22kline_type%22:%209,%20%22kline_timestamp_end%22:%200,%20%22query_kline_num%22:%20100,%20%22adjust_type%22:%200%20}%20}'

resp=requests.get(url=klines_100w_url,headers=test_headers)
