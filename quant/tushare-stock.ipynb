# %%
import tushare as ts

ts.set_token("dcb1b6656abcd5639827616df7e32fc117dc3454c973955fd5a31f2a")

pro=ts.pro_api()

pro.trade_cal(exchange='', start_date='20180901', end_date='20181001', fields='exchange,cal_date,is_open,pretrade_date', is_open='0')
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 7
#       3 ts.set_token("dcb1b6656abcd5639827616df7e32fc117dc3454c973955fd5a31f2a")
#       5 pro=ts.pro_api()
# ----> 7 pro.trade_cal(exchange='', start_date='20180901', end_date='20181001', fields='exchange,cal_date,is_open,pretrade_date', is_open='0')
#
# File ~/.local/lib/python3.12/site-packages/tushare/pro/client.py:45, in DataApi.query(self, api_name, fields, **kwargs)
#      43 result = json.loads(res.text)
#      44 if result['code'] != 0:
# ---> 45     raise Exception(result['msg'])
#      46 data = result['data']
#      47 columns = data['fields']
#
# Exception: 抱歉，您没有接口访问权限，权限的具体详情访问：https://tushare.pro/document/1?doc_id=108。
